# %%
from sympy import *;import sympy;import random;from sympy.core.symbol import symbols;from sympy.solvers.solveset import nonlinsolve
from lib import *
init_printing()
a, b, c, d, d1, d2, d3 = symbols('a, b, c, d, d1, d2, d3')
a0, a1,a2, a3,a4, a5,a6,a7,a8,a9,a10, b1 = symbols('a0, a1, a2, a3,a4,a5,a6,a7,a8, a9, a10, b1')
m, L, H0 = symbols('m, L, H0');x, y = symbols('x, y');v0, v1 = symbols('v0, v1')

# %%
H0_, L_ = 1, 10;m_, v0_ = 1, 2;v1_ = 12/5*v0_
H = H0
Tx = a0 + a1 * x + a2 * y + a3 * x ** 2 + a4 * x **3
vx = v0 * (1- x/L) + v1 *(H**2-y**2)*(1+x/L)  + (1-x**2/L**2)*(H ** 2 - y ** 2) * Tx
p = d1 * x #+ d2 * x ** 2  
print("vx=", vx);print("p=", p)
# checking profiles
print("vx(-L, y) =", substitute(vx, [x], [-L]));print("vx(L, y) =", substitute(vx, [x], [L]))
print("H(-L) =", substitute(H, [x], [-L]));print("H(L) =", substitute(H, [x], [L]))
# Out:
# vx= v0*(1 - x/L) + v1*(1 + x/L)*(H0**2 - y**2) + (1 - x**2/L**2)*(H0**2 - y**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3)
# p= d1*x
# vx(-L, y) = 2*v0
# vx(L, y) = 2*v1*(H0**2 - y**2)
# H(-L) = H0
# H(L) = H0

# %%
vy = 0

# %%
pxx = -p * 1 + m * (diff(vx, x) + diff(vx, x));pxy = -p * 0 + m * (diff(vx, y) + diff(vy, x));pyy = -p * 1 + m * (diff(vy, y) + diff(vy, y))
p2ij = pxx ** 2 + 2 * pxy ** 2 + pyy ** 2;f = p2ij - 2 * (p ** 2) 
# f = substitute(f, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
print("f=", f);   print('1. Integrating ...')
fx = integrate(f, (y, -H, H)) 
# fx = substitute(fx, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
print("fx=", fx); print('2. Integrating ...')
g = integrate(fx, (x, -L_, L_))
# g = substitute(g, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
print('g=', end='')
pprint(g)
print('='*50)
# Out:
# f= -d1**2*x**2 + 2*m**2*(a2*(1 - x**2/L**2)*(H0**2 - y**2) - 2*v1*y*(1 + x/L) - 2*y*(1 - x**2/L**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3))**2 + (-d1*x + m*(2*(1 - x**2/L**2)*(H0**2 - y**2)*(a1 + 2*a3*x + 3*a4*x**2) - 2*v0/L + 2*v1*(H0**2 - y**2)/L - 4*x*(H0**2 - y**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3)/L**2))**2
# 1. Integrating ...
# fx= 32*H0**7*a2**2*m**2*x**2/(7*L**4) + 2*H0**5*(-32*H0**2*a2**2*m**2*x**2 + 4*L**4*a1**2*m**2 + 16*L**4*a1*a3*m**2*x + 24*L**4*a1*a4*m**2*x**2 + 18*L**4*a2**2*m**2 + 16*L**4*a3**2*m**2*x**2 + 48*L**4*a3*a4*m**2*x**3 + 36*L**4*a4**2*m**2*x**4 + 8*L**3*a1*m**2*v1 + 16*L**3*a3*m**2*v1*x + 24*L**3*a4*m**2*v1*x**2 - 16*L**2*a0*a1*m**2*x - 32*L**2*a0*a3*m**2*x**2 - 48*L**2*a0*a4*m**2*x**3 - 24*L**2*a1**2*m**2*x**2 - 80*L**2*a1*a3*m**2*x**3 - 112*L**2*a1*a4*m**2*x**4 - 36*L**2*a2**2*m**2*x**2 - 64*L**2*a3**2*m**2*x**4 - 176*L**2*a3*a4*m**2*x**5 - 120*L**2*a4**2*m**2*x**6 + 4*L**2*m**2*v1**2 - 16*L*a0*m**2*v1*x - 24*L*a1*m**2*v1*x**2 - 32*L*a3*m**2*v1*x**3 - 40*L*a4*m**2*v1*x**4 + 16*a0**2*m**2*x**2 + 48*a0*a1*m**2*x**3 + 64*a0*a3*m**2*x**4 + 80*a0*a4*m**2*x**5 + 36*a1**2*m**2*x**4 + 96*a1*a3*m**2*x**5 + 120*a1*a4*m**2*x**6 + 18*a2**2*m**2*x**4 + 64*a3**2*m**2*x**6 + 160*a3*a4*m**2*x**7 + 100*a4**2*m**2*x**8)/(5*L**4) + 2*H0**3*(16*H0**4*a2**2*m**2*x**2 - 8*H0**2*L**4*a1**2*m**2 - 32*H0**2*L**4*a1*a3*m**2*x - 48*H0**2*L**4*a1*a4*m**2*x**2 - 12*H0**2*L**4*a2**2*m**2 - 32*H0**2*L**4*a3**2*m**2*x**2 - 96*H0**2*L**4*a3*a4*m**2*x**3 - 72*H0**2*L**4*a4**2*m**2*x**4 - 16*H0**2*L**3*a1*m**2*v1 - 32*H0**2*L**3*a3*m**2*v1*x - 48*H0**2*L**3*a4*m**2*v1*x**2 + 32*H0**2*L**2*a0*a1*m**2*x + 64*H0**2*L**2*a0*a3*m**2*x**2 + 96*H0**2*L**2*a0*a4*m**2*x**3 + 48*H0**2*L**2*a1**2*m**2*x**2 + 160*H0**2*L**2*a1*a3*m**2*x**3 + 224*H0**2*L**2*a1*a4*m**2*x**4 + 24*H0**2*L**2*a2**2*m**2*x**2 + 128*H0**2*L**2*a3**2*m**2*x**4 + 352*H0**2*L**2*a3*a4*m**2*x**5 + 240*H0**2*L**2*a4**2*m**2*x**6 - 8*H0**2*L**2*m**2*v1**2 + 32*H0**2*L*a0*m**2*v1*x + 48*H0**2*L*a1*m**2*v1*x**2 + 64*H0**2*L*a3*m**2*v1*x**3 + 80*H0**2*L*a4*m**2*v1*x**4 - 32*H0**2*a0**2*m**2*x**2 - 96*H0**2*a0*a1*m**2*x**3 - 128*H0**2*a0*a3*m**2*x**4 - 160*H0**2*a0*a4*m**2*x**5 - 72*H0**2*a1**2*m**2*x**4 - 192*H0**2*a1*a3*m**2*x**5 - 240*H0**2*a1*a4*m**2*x**6 - 12*H0**2*a2**2*m**2*x**4 - 128*H0**2*a3**2*m**2*x**6 - 320*H0**2*a3*a4*m**2*x**7 - 200*H0**2*a4**2*m**2*x**8 + 8*L**4*a0**2*m**2 + 16*L**4*a0*a1*m**2*x + 16*L**4*a0*a3*m**2*x**2 + 16*L**4*a0*a4*m**2*x**3 + 16*L**4*a0*m**2*v1 + 8*L**4*a1**2*m**2*x**2 + 16*L**4*a1*a3*m**2*x**3 + 16*L**4*a1*a4*m**2*x**4 + 4*L**4*a1*d1*m*x + 16*L**4*a1*m**2*v1*x + 8*L**4*a3**2*m**2*x**4 + 16*L**4*a3*a4*m**2*x**5 + 8*L**4*a3*d1*m*x**2 + 16*L**4*a3*m**2*v1*x**2 + 8*L**4*a4**2*m**2*x**6 + 12*L**4*a4*d1*m*x**3 + 16*L**4*a4*m**2*v1*x**3 + 8*L**4*m**2*v1**2 + 16*L**3*a0*m**2*v1*x + 8*L**3*a1*m**2*v0 + 16*L**3*a1*m**2*v1*x**2 + 16*L**3*a3*m**2*v0*x + 16*L**3*a3*m**2*v1*x**3 + 24*L**3*a4*m**2*v0*x**2 + 16*L**3*a4*m**2*v1*x**4 + 4*L**3*d1*m*v1*x + 16*L**3*m**2*v1**2*x - 16*L**2*a0**2*m**2*x**2 - 32*L**2*a0*a1*m**2*x**3 - 32*L**2*a0*a3*m**2*x**4 - 32*L**2*a0*a4*m**2*x**5 - 8*L**2*a0*d1*m*x**2 - 16*L**2*a0*m**2*v1*x**2 - 16*L**2*a1**2*m**2*x**4 - 32*L**2*a1*a3*m**2*x**5 - 32*L**2*a1*a4*m**2*x**6 - 12*L**2*a1*d1*m*x**3 - 16*L**2*a1*m**2*v1*x**3 - 16*L**2*a3**2*m**2*x**6 - 32*L**2*a3*a4*m**2*x**7 - 16*L**2*a3*d1*m*x**4 - 16*L**2*a3*m**2*v1*x**4 - 16*L**2*a4**2*m**2*x**8 - 20*L**2*a4*d1*m*x**5 - 16*L**2*a4*m**2*v1*x**5 + 8*L**2*m**2*v0*v1 + 8*L**2*m**2*v1**2*x**2 - 16*L*a0*m**2*v0*x - 16*L*a0*m**2*v1*x**3 - 24*L*a1*m**2*v0*x**2 - 16*L*a1*m**2*v1*x**4 - 32*L*a3*m**2*v0*x**3 - 16*L*a3*m**2*v1*x**5 - 40*L*a4*m**2*v0*x**4 - 16*L*a4*m**2*v1*x**6 + 8*a0**2*m**2*x**4 + 16*a0*a1*m**2*x**5 + 16*a0*a3*m**2*x**6 + 16*a0*a4*m**2*x**7 + 8*a1**2*m**2*x**6 + 16*a1*a3*m**2*x**7 + 16*a1*a4*m**2*x**8 + 8*a3**2*m**2*x**8 + 16*a3*a4*m**2*x**9 + 8*a4**2*m**2*x**10)/(3*L**4) + 2*H0*(4*H0**4*L**4*a1**2*m**2 + 16*H0**4*L**4*a1*a3*m**2*x + 24*H0**4*L**4*a1*a4*m**2*x**2 + 2*H0**4*L**4*a2**2*m**2 + 16*H0**4*L**4*a3**2*m**2*x**2 + 48*H0**4*L**4*a3*a4*m**2*x**3 + 36*H0**4*L**4*a4**2*m**2*x**4 + 8*H0**4*L**3*a1*m**2*v1 + 16*H0**4*L**3*a3*m**2*v1*x + 24*H0**4*L**3*a4*m**2*v1*x**2 - 16*H0**4*L**2*a0*a1*m**2*x - 32*H0**4*L**2*a0*a3*m**2*x**2 - 48*H0**4*L**2*a0*a4*m**2*x**3 - 24*H0**4*L**2*a1**2*m**2*x**2 - 80*H0**4* ...
# 2. Integrating ...
# g=                3   2  2     ⎛     5  2   2  2        5  2   2  2         5
# 3200000000000⋅H₀ ⋅a₄ ⋅m    4⋅⎝64⋅H₀ ⋅L ⋅a₁ ⋅m  + 48⋅H₀ ⋅L ⋅a₂ ⋅m  + 128⋅H₀ ⋅L⋅
# ──────────────────────── + ───────────────────────────────────────────────────
#              4
#          33⋅L
#
#     2           5  2   2        3  2   2  2         3  2     2           3  2
# a₁⋅m ⋅v₁ + 64⋅H₀ ⋅m ⋅v₁  + 80⋅H₀ ⋅L ⋅a₀ ⋅m  + 160⋅H₀ ⋅L ⋅a₀⋅m ⋅v₁ + 80⋅H₀ ⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                               2
#                                            3⋅L
#
#  2   2         3       2            3  2                 2   2⎞              ⎛
# m ⋅v₁  - 160⋅H₀ ⋅L⋅a₁⋅m ⋅v₀ - 160⋅H₀ ⋅m ⋅v₀⋅v₁ + 120⋅H₀⋅m ⋅v₀ ⎠   2000000000⋅⎝
# ─────────────────────────────────────────────────────────────── + ────────────
#
#
#
#       5   2  2        3  2   2  2        3        2        3   2  2⎞
# 320⋅H₀ ⋅a₄ ⋅m  - 32⋅H₀ ⋅L ⋅a₄ ⋅m  + 32⋅H₀ ⋅a₁⋅a₄⋅m  + 16⋅H₀ ⋅a₃ ⋅m ⎠   4000000
# ──────────────────────────────────────────────────────────────────── + ───────
#                              4
#                          27⋅L
#
#  ⎛         5  2   2  2          5        2          5   2  2        3  4   2
# ⋅⎝- 1920⋅H₀ ⋅L ⋅a₄ ⋅m  + 1920⋅H₀ ⋅a₁⋅a₄⋅m  + 1024⋅H₀ ⋅a₃ ⋅m  + 80⋅H₀ ⋅L ⋅a₄ ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2         3  2        2         3  2   2  2         3       2            3
#   - 320⋅H₀ ⋅L ⋅a₁⋅a₄⋅m  - 160⋅H₀ ⋅L ⋅a₃ ⋅m  - 160⋅H₀ ⋅L⋅a₄⋅m ⋅v₁ + 160⋅H₀ ⋅a₀⋅
# ──────────────────────────────────────────────────────────────────────────────
#          4
#      21⋅L
#
#     2        3   2  2⎞        ⎛      5  4   2  2          5  2        2
# a₃⋅m  + 80⋅H₀ ⋅a₁ ⋅m ⎠   8000⋅⎝576⋅H₀ ⋅L ⋅a₄ ⋅m  - 1792⋅H₀ ⋅L ⋅a₁⋅a₄⋅m  - 1024
# ────────────────────── + ─────────────────────────────────────────────────────
#
#
#
#    5  2   2  2         5       2             5        2         5   2  2
# ⋅H₀ ⋅L ⋅a₃ ⋅m  - 640⋅H₀ ⋅L⋅a₄⋅m ⋅v₁ + 1024⋅H₀ ⋅a₀⋅a₃⋅m  + 576⋅H₀ ⋅a₁ ⋅m  + 48⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   5   2  2         3  4        2        3  4   2  2         3  3     2
# H₀ ⋅a₂ ⋅m  + 160⋅H₀ ⋅L ⋅a₁⋅a₄⋅m  + 80⋅H₀ ⋅L ⋅a₃ ⋅m  + 160⋅H₀ ⋅L ⋅a₄⋅m ⋅v₁ - 32
# ──────────────────────────────────────────────────────────────────────────────
#                                             4
#                                          3⋅L
#
#     3  2        2         3  2   2  2         3  2                 3  2     2
# 0⋅H₀ ⋅L ⋅a₀⋅a₃⋅m  - 160⋅H₀ ⋅L ⋅a₁ ⋅m  + 320⋅H₀ ⋅L ⋅a₃⋅d₁⋅m - 160⋅H₀ ⋅L ⋅a₃⋅m ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            3       2            3       2           3   2  2⎞       ⎛      7
# v₁ - 160⋅H₀ ⋅L⋅a₁⋅m ⋅v₁ + 800⋅H₀ ⋅L⋅a₄⋅m ⋅v₀ + 80⋅H₀ ⋅a₀ ⋅m ⎠   400⋅⎝256⋅H₀ ⋅a
# ───────────────────────────────────────────────────────────── + ──────────────
#
#
#
#  2  2          5  4        2          5  4   2  2          5  3     2
# ₂ ⋅m  + 2688⋅H₀ ⋅L ⋅a₁⋅a₄⋅m  + 1792⋅H₀ ⋅L ⋅a₃ ⋅m  + 2688⋅H₀ ⋅L ⋅a₄⋅m ⋅v₁ - 358
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     5  2        2          5  2   2  2         5  2   2  2          5       2
# 4⋅H₀ ⋅L ⋅a₀⋅a₃⋅m  - 2688⋅H₀ ⋅L ⋅a₁ ⋅m  - 672⋅H₀ ⋅L ⋅a₂ ⋅m  - 2688⋅H₀ ⋅L⋅a₁⋅m ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             5   2  2          3  4        2         3  4   2  2          3  4
# v₁ + 1792⋅H₀ ⋅a₀ ⋅m  + 1120⋅H₀ ⋅L ⋅a₀⋅a₃⋅m  + 560⋅H₀ ⋅L ⋅a₁ ⋅m  - 1120⋅H₀ ⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                 4
#                                             63⋅L
#
#                  3  4     2             3  3     2             3  3     2
# a₃⋅d₁⋅m + 1120⋅H₀ ⋅L ⋅a₃⋅m ⋅v₁ + 1120⋅H₀ ⋅L ⋅a₁⋅m ⋅v₁ - 3360⋅H₀ ⋅L ⋅a₄⋅m ⋅v₀ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         3  2   2  2          3  2                  3  2     2            3  2
#  1120⋅H₀ ⋅L ⋅a₀ ⋅m  + 1120⋅H₀ ⋅L ⋅a₀⋅d₁⋅m - 1120⋅H₀ ⋅L ⋅a₀⋅m ⋅v₁ + 560⋅H₀ ⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2   2          3       2   ⎞
# m ⋅v₁  + 3360⋅H₀ ⋅L⋅a₁⋅m ⋅v₀⎠
# ─────────────────────────────
#
#
# ==================================================

# %%
# g = substitute(g, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
#for i in
d_a0 = diff(g, a0);d_a1 = diff(g, a1);d_a2 = diff(g, a2);d_a3 = diff(g, a3);d_a4 = diff(g, a4);
d_d1 = diff(g, d1);d_d2 = diff(g, d2)
# p2 = substitute(p,[x], [L_]) - 1
p2 = substitute(p,[x], [L_]) - 1;p1 = substitute(p, [x], [-L_])
print("d_a0=", d_a0);print("d_a1=", d_a1);print("d_a2", d_a2);print("d_a3=", d_a3);print("d_a4", d_a4);
print("d_d1=", d_d1);print("d_d2=", d_d2);print("p2=", p2);print('=' * 100)
# Out:
# d_a0= 640000000*H0**3*a3*m**2/(21*L**4) + 4*(160*H0**3*L**2*a0*m**2 + 160*H0**3*L**2*m**2*v1)/(3*L**2) + 8000*(1024*H0**5*a3*m**2 - 320*H0**3*L**2*a3*m**2 + 160*H0**3*a0*m**2)/(3*L**4) + 400*(-3584*H0**5*L**2*a3*m**2 + 3584*H0**5*a0*m**2 + 1120*H0**3*L**4*a3*m**2 - 2240*H0**3*L**2*a0*m**2 + 1120*H0**3*L**2*d1*m - 1120*H0**3*L**2*m**2*v1)/(63*L**4)
# d_a1= 64000000000*H0**3*a4*m**2/(27*L**4) + 4*(128*H0**5*L**2*a1*m**2 + 128*H0**5*L*m**2*v1 - 160*H0**3*L*m**2*v0)/(3*L**2) + 4000000*(1920*H0**5*a4*m**2 - 320*H0**3*L**2*a4*m**2 + 160*H0**3*a1*m**2)/(21*L**4) + 8000*(-1792*H0**5*L**2*a4*m**2 + 1152*H0**5*a1*m**2 + 160*H0**3*L**4*a4*m**2 - 320*H0**3*L**2*a1*m**2 - 160*H0**3*L*m**2*v1)/(3*L**4) + 400*(2688*H0**5*L**4*a4*m**2 - 5376*H0**5*L**2*a1*m**2 - 2688*H0**5*L*m**2*v1 + 1120*H0**3*L**4*a1*m**2 + 1120*H0**3*L**3*m**2*v1 + 3360*H0**3*L*m**2*v0)/(63*L**4)
# d_a2 128*H0**5*a2*m**2 + 256000*H0**5*a2*m**2/L**4 + 400*(512*H0**7*a2*m**2 - 1344*H0**5*L**2*a2*m**2)/(63*L**4)
# d_a3= 64000000000*H0**3*a3*m**2/(27*L**4) + 4000000*(2048*H0**5*a3*m**2 - 320*H0**3*L**2*a3*m**2 + 160*H0**3*a0*m**2)/(21*L**4) + 400*(3584*H0**5*L**4*a3*m**2 - 3584*H0**5*L**2*a0*m**2 + 1120*H0**3*L**4*a0*m**2 - 1120*H0**3*L**4*d1*m + 1120*H0**3*L**4*m**2*v1)/(63*L**4) + 8000*(-2048*H0**5*L**2*a3*m**2 + 1024*H0**5*a0*m**2 + 160*H0**3*L**4*a3*m**2 - 320*H0**3*L**2*a0*m**2 + 320*H0**3*L**2*d1*m - 160*H0**3*L**2*m**2*v1)/(3*L**4)
# d_a4 6400000000000*H0**3*a4*m**2/(33*L**4) + 2000000000*(640*H0**5*a4*m**2 - 64*H0**3*L**2*a4*m**2 + 32*H0**3*a1*m**2)/(27*L**4) + 400*(2688*H0**5*L**4*a1*m**2 + 2688*H0**5*L**3*m**2*v1 - 3360*H0**3*L**3*m**2*v0)/(63*L**4) + 4000000*(-3840*H0**5*L**2*a4*m**2 + 1920*H0**5*a1*m**2 + 160*H0**3*L**4*a4*m**2 - 320*H0**3*L**2*a1*m**2 - 160*H0**3*L*m**2*v1)/(21*L**4) + 8000*(1152*H0**5*L**4*a4*m**2 - 1792*H0**5*L**2*a1*m**2 - 640*H0**5*L*m**2*v1 + 160*H0**3*L**4*a1*m**2 + 160*H0**3*L**3*m**2*v1 + 800*H0**3*L*m**2*v0)/(3*L**4)
# d_d1= 2560000*H0**3*a3*m/(3*L**2) + 400*(-1120*H0**3*L**4*a3*m + 1120*H0**3*L**2*a0*m)/(63*L**4)
# d_d2= 0
# p2= 10*d1 - 1
# ====================================================================================================

# %%
print('1. Solving all partial derivatives equal to 0')
variables =[a0,a1,a2,a3,a4, d1, d2]
result = solve([d_a0,d_a1,d_a2, d_a3,d_a4, d_d1, d_d2], variables)
if len(result) == 0:
    print('No solutions!')
else:
    print('1. Building plot')
    vx1 = substitute(vx, variables, result[0])
    print('=' * 100)
    vx1 = substitute(vx1, [v0,v1, H0, L], [v0_,v1_,  H0_, L_])
    print("vx = ", vx);print("vx1 = ", vx1);print('-' * 100)
    vx1 = substitute(vx1, [y], [0]) 
    print("vx1 = ", vx1);print('=' * 100)
    pl1 = sympy.plotting.plot(vx1, xlim=(-L_, (L_ + 0.1)), ylim=(-(10 + 1), (10+1)), ylabel='vx')
# Out:
# 1. Solving all partial derivatives equal to 0
# --------------------------------------------------
# Solving for variables [a0, a1, a2, a3, a4, d1, d2]
# Amount of solutions 32
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 =       ⎛           4  7                   4  5                     4  3
# -0.375⋅⎝116424.0⋅H₀ ⋅L ⋅v₁ - 33264000.0⋅H₀ ⋅L ⋅v₁ + 3086160000.0⋅H₀ ⋅L ⋅v₁ - 9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                4                   2  7                  2  7
# 2400000000.0⋅H₀ ⋅L⋅v₁ - 145530.0⋅H₀ ⋅L ⋅v₀ + 6237000.0⋅H₀ ⋅L ⋅v₁ + 41580000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             4  8                4  6                  4  4                   4
#   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 69300000000.0⋅H₀
#
#   2  5                     2  5                     2  3
# H₀ ⋅L ⋅v₀ - 1755600000.0⋅H₀ ⋅L ⋅v₁ - 3857700000.0⋅H₀ ⋅L ⋅v₀ + 158410000000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#   2                     4               2  8                 2  6
# ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀ ⋅L  + 6893250000
#
#  2  3                       2                          2                   7
# ₀ ⋅L ⋅v₁ + 115500000000.0⋅H₀ ⋅L⋅v₀ - 4170000000000.0⋅H₀ ⋅L⋅v₁ + 1299375.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#       2  4                     2  2                      2              8
# 0.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6496875.0⋅L  - 14
#
#                 7                   5                    5
# ₀ + 17325000.0⋅L ⋅v₁ - 274312500.0⋅L ⋅v₀ - 3850000000.0⋅L ⋅v₁ + 19031250000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             6                   4                    2
# 43750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687500000000.0
#
#  3                      3                                                ⎞
# L ⋅v₀ + 266250000000.0⋅L ⋅v₁ - 459375000000.0⋅L⋅v₀ - 5250000000000.0⋅L⋅v₁⎠
# ───────────────────────────────────────────────────────────────────────────
#
#
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 =         ⎛          4  5                  4  3                    4
# -1.03125⋅⎝42336.0⋅H₀ ⋅L ⋅v₁ - 6048000.0⋅H₀ ⋅L ⋅v₁ + 181440000.0⋅H₀ ⋅L⋅v₁ - 529
# ──────────────────────────────────────────────────────────────────────────────
#                             4  8                4  6                  4  4
#                   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 6
#
#        2  5                  2  5                  2  3                    2
# 20.0⋅H₀ ⋅L ⋅v₀ + 2268000.0⋅H₀ ⋅L ⋅v₁ + 7560000.0⋅H₀ ⋅L ⋅v₀ - 319200000.0⋅H₀ ⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                4  2                     4               2  8                 2
# 9300000000.0⋅H₀ ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀
#
# 3                    2                       2                 7
#  ⋅v₁ - 226800000.0⋅H₀ ⋅L⋅v₀ + 9240000000.0⋅H₀ ⋅L⋅v₁ - 11025.0⋅L ⋅v₀ + 2047500.
# ──────────────────────────────────────────────────────────────────────────────
#   6                   2  4                     2  2                      2
# ⋅L  + 68932500000.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6
#
#    5                 5                   3                   3
# 0⋅L ⋅v₀ + 6300000.0⋅L ⋅v₁ - 120750000.0⋅L ⋅v₀ - 700000000.0⋅L ⋅v₁ + 2625000000
# ──────────────────────────────────────────────────────────────────────────────
#           8                 6                   4                    2
# 496875.0⋅L  - 1443750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687
#
#                             ⎞
# .0⋅L⋅v₀ + 15000000000.0⋅L⋅v₁⎠
# ──────────────────────────────
#
# 500000000.0
# d1 =        ⎛        2  2                  2              4                2
# -1280.0⋅⎝432.0⋅H₀ ⋅L ⋅m⋅v₁ - 14400.0⋅H₀ ⋅m⋅v₁ + 45.0⋅L ⋅m⋅v₁ - 3000.0⋅L ⋅m⋅v₁
# ──────────────────────────────────────────────────────────────────────────────
#                    2         8            6              4               2
#       18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3
#
#               ⎞
# + 10000.0⋅m⋅v₁⎠
# ────────────────
#
# 54400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 =       ⎛           4  7                   4  5                     4  3
# -0.375⋅⎝116424.0⋅H₀ ⋅L ⋅v₁ - 33264000.0⋅H₀ ⋅L ⋅v₁ + 3086160000.0⋅H₀ ⋅L ⋅v₁ - 9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                4                   2  7                  2  7
# 2400000000.0⋅H₀ ⋅L⋅v₁ - 145530.0⋅H₀ ⋅L ⋅v₀ + 6237000.0⋅H₀ ⋅L ⋅v₁ + 41580000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             4  8                4  6                  4  4                   4
#   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 69300000000.0⋅H₀
#
#   2  5                     2  5                     2  3
# H₀ ⋅L ⋅v₀ - 1755600000.0⋅H₀ ⋅L ⋅v₁ - 3857700000.0⋅H₀ ⋅L ⋅v₀ + 158410000000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#   2                     4               2  8                 2  6
# ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀ ⋅L  + 6893250000
#
#  2  3                       2                          2                   7
# ₀ ⋅L ⋅v₁ + 115500000000.0⋅H₀ ⋅L⋅v₀ - 4170000000000.0⋅H₀ ⋅L⋅v₁ + 1299375.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#       2  4                     2  2                      2              8
# 0.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6496875.0⋅L  - 14
#
#                 7                   5                    5
# ₀ + 17325000.0⋅L ⋅v₁ - 274312500.0⋅L ⋅v₀ - 3850000000.0⋅L ⋅v₁ + 19031250000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             6                   4                    2
# 43750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687500000000.0
#
#  3                      3                                                ⎞
# L ⋅v₀ + 266250000000.0⋅L ⋅v₁ - 459375000000.0⋅L⋅v₀ - 5250000000000.0⋅L⋅v₁⎠
# ───────────────────────────────────────────────────────────────────────────
#
#
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 =         ⎛          4  5                  4  3                    4
# -1.03125⋅⎝42336.0⋅H₀ ⋅L ⋅v₁ - 6048000.0⋅H₀ ⋅L ⋅v₁ + 181440000.0⋅H₀ ⋅L⋅v₁ - 529
# ──────────────────────────────────────────────────────────────────────────────
#                             4  8                4  6                  4  4
#                   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 6
#
#        2  5                  2  5                  2  3                    2
# 20.0⋅H₀ ⋅L ⋅v₀ + 2268000.0⋅H₀ ⋅L ⋅v₁ + 7560000.0⋅H₀ ⋅L ⋅v₀ - 319200000.0⋅H₀ ⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                4  2                     4               2  8                 2
# 9300000000.0⋅H₀ ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀
#
# 3                    2                       2                 7
#  ⋅v₁ - 226800000.0⋅H₀ ⋅L⋅v₀ + 9240000000.0⋅H₀ ⋅L⋅v₁ - 11025.0⋅L ⋅v₀ + 2047500.
# ──────────────────────────────────────────────────────────────────────────────
#   6                   2  4                     2  2                      2
# ⋅L  + 68932500000.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6
#
#    5                 5                   3                   3
# 0⋅L ⋅v₀ + 6300000.0⋅L ⋅v₁ - 120750000.0⋅L ⋅v₀ - 700000000.0⋅L ⋅v₁ + 2625000000
# ──────────────────────────────────────────────────────────────────────────────
#           8                 6                   4                    2
# 496875.0⋅L  - 1443750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687
#
#                             ⎞
# .0⋅L⋅v₀ + 15000000000.0⋅L⋅v₁⎠
# ──────────────────────────────
#
# 500000000.0
# d1 = ⎛           2  2                     2                 4                   2
# -⎝552960.0⋅H₀ ⋅L ⋅m⋅v₁ - 18432000.0⋅H₀ ⋅m⋅v₁ + 57600.0⋅L ⋅m⋅v₁ - 3840000.0⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                        2         8            6              4               2
#           18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L
#
#                       ⎞
# m⋅v₁ + 12800000.0⋅m⋅v₁⎠
# ────────────────────────
#
#  + 354400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 =       ⎛           4  7                   4  5                     4  3
# -0.375⋅⎝116424.0⋅H₀ ⋅L ⋅v₁ - 33264000.0⋅H₀ ⋅L ⋅v₁ + 3086160000.0⋅H₀ ⋅L ⋅v₁ - 9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                4                   2  7                  2  7
# 2400000000.0⋅H₀ ⋅L⋅v₁ - 145530.0⋅H₀ ⋅L ⋅v₀ + 6237000.0⋅H₀ ⋅L ⋅v₁ + 41580000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             4  8                4  6                  4  4                   4
#   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 69300000000.0⋅H₀
#
#   2  5                     2  5                     2  3
# H₀ ⋅L ⋅v₀ - 1755600000.0⋅H₀ ⋅L ⋅v₁ - 3857700000.0⋅H₀ ⋅L ⋅v₀ + 158410000000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#   2                     4               2  8                 2  6
# ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀ ⋅L  + 6893250000
#
#  2  3                       2                          2                   7
# ₀ ⋅L ⋅v₁ + 115500000000.0⋅H₀ ⋅L⋅v₀ - 4170000000000.0⋅H₀ ⋅L⋅v₁ + 1299375.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#       2  4                     2  2                      2              8
# 0.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6496875.0⋅L  - 14
#
#                 7                   5                    5
# ₀ + 17325000.0⋅L ⋅v₁ - 274312500.0⋅L ⋅v₀ - 3850000000.0⋅L ⋅v₁ + 19031250000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             6                   4                    2
# 43750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687500000000.0
#
#  3                      3                                                ⎞
# L ⋅v₀ + 266250000000.0⋅L ⋅v₁ - 459375000000.0⋅L⋅v₀ - 5250000000000.0⋅L⋅v₁⎠
# ───────────────────────────────────────────────────────────────────────────
#
#
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 = ⎛            4  5                    4  3                     4
# -⎝1397088.0⋅H₀ ⋅L ⋅v₁ - 199584000.0⋅H₀ ⋅L ⋅v₁ + 5987520000.0⋅H₀ ⋅L⋅v₁ - 174636
# ──────────────────────────────────────────────────────────────────────────────
#                                    4  8                 4  6
#                        1397088.0⋅H₀ ⋅L  - 399168000.0⋅H₀ ⋅L  + 43021440000.0⋅H
#
#       2  5                   2  5                    2  3
# 0.0⋅H₀ ⋅L ⋅v₀ + 74844000.0⋅H₀ ⋅L ⋅v₁ + 249480000.0⋅H₀ ⋅L ⋅v₀ - 10533600000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#  4  4                     4  2                      4                2  8
# ₀ ⋅L  - 2217600000000.0⋅H₀ ⋅L  + 71280000000000.0⋅H₀  + 74844000.0⋅H₀ ⋅L  - 21
#
#  2  3                     2                         2                  7
# ₀ ⋅L ⋅v₁ - 7484400000.0⋅H₀ ⋅L⋅v₀ + 304920000000.0⋅H₀ ⋅L⋅v₁ - 363825.0⋅L ⋅v₀ +
# ──────────────────────────────────────────────────────────────────────────────
#               2  6                     2  4                       2  2
# 067200000.0⋅H₀ ⋅L  + 2205840000000.0⋅H₀ ⋅L  - 100080000000000.0⋅H₀ ⋅L  + 1.839
#
#             5                   5                    3                     3
# 67567500.0⋅L ⋅v₀ + 207900000.0⋅L ⋅v₁ - 3984750000.0⋅L ⋅v₀ - 23100000000.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#         2                8                  6                    4
# 6e+15⋅H₀  + 207900000.0⋅L  - 46200000000.0⋅L  + 3690000000000.0⋅L  - 126000000
#
#                                             ⎞
# ₁ + 86625000000.0⋅L⋅v₀ + 495000000000.0⋅L⋅v₁⎠
# ──────────────────────────────────────────────
#           2
# 000000.0⋅L  + 1.75e+15
# d1 =        ⎛        2  2                  2              4                2
# -1280.0⋅⎝432.0⋅H₀ ⋅L ⋅m⋅v₁ - 14400.0⋅H₀ ⋅m⋅v₁ + 45.0⋅L ⋅m⋅v₁ - 3000.0⋅L ⋅m⋅v₁
# ──────────────────────────────────────────────────────────────────────────────
#                    2         8            6              4               2
#       18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3
#
#               ⎞
# + 10000.0⋅m⋅v₁⎠
# ────────────────
#
# 54400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 =       ⎛           4  7                   4  5                     4  3
# -0.375⋅⎝116424.0⋅H₀ ⋅L ⋅v₁ - 33264000.0⋅H₀ ⋅L ⋅v₁ + 3086160000.0⋅H₀ ⋅L ⋅v₁ - 9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                4                   2  7                  2  7
# 2400000000.0⋅H₀ ⋅L⋅v₁ - 145530.0⋅H₀ ⋅L ⋅v₀ + 6237000.0⋅H₀ ⋅L ⋅v₁ + 41580000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             4  8                4  6                  4  4                   4
#   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 69300000000.0⋅H₀
#
#   2  5                     2  5                     2  3
# H₀ ⋅L ⋅v₀ - 1755600000.0⋅H₀ ⋅L ⋅v₁ - 3857700000.0⋅H₀ ⋅L ⋅v₀ + 158410000000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#   2                     4               2  8                 2  6
# ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀ ⋅L  + 6893250000
#
#  2  3                       2                          2                   7
# ₀ ⋅L ⋅v₁ + 115500000000.0⋅H₀ ⋅L⋅v₀ - 4170000000000.0⋅H₀ ⋅L⋅v₁ + 1299375.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#       2  4                     2  2                      2              8
# 0.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6496875.0⋅L  - 14
#
#                 7                   5                    5
# ₀ + 17325000.0⋅L ⋅v₁ - 274312500.0⋅L ⋅v₀ - 3850000000.0⋅L ⋅v₁ + 19031250000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             6                   4                    2
# 43750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687500000000.0
#
#  3                      3                                                ⎞
# L ⋅v₀ + 266250000000.0⋅L ⋅v₁ - 459375000000.0⋅L⋅v₀ - 5250000000000.0⋅L⋅v₁⎠
# ───────────────────────────────────────────────────────────────────────────
#
#
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 = ⎛            4  5                    4  3                     4
# -⎝1397088.0⋅H₀ ⋅L ⋅v₁ - 199584000.0⋅H₀ ⋅L ⋅v₁ + 5987520000.0⋅H₀ ⋅L⋅v₁ - 174636
# ──────────────────────────────────────────────────────────────────────────────
#                                    4  8                 4  6
#                        1397088.0⋅H₀ ⋅L  - 399168000.0⋅H₀ ⋅L  + 43021440000.0⋅H
#
#       2  5                   2  5                    2  3
# 0.0⋅H₀ ⋅L ⋅v₀ + 74844000.0⋅H₀ ⋅L ⋅v₁ + 249480000.0⋅H₀ ⋅L ⋅v₀ - 10533600000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#  4  4                     4  2                      4                2  8
# ₀ ⋅L  - 2217600000000.0⋅H₀ ⋅L  + 71280000000000.0⋅H₀  + 74844000.0⋅H₀ ⋅L  - 21
#
#  2  3                     2                         2                  7
# ₀ ⋅L ⋅v₁ - 7484400000.0⋅H₀ ⋅L⋅v₀ + 304920000000.0⋅H₀ ⋅L⋅v₁ - 363825.0⋅L ⋅v₀ +
# ──────────────────────────────────────────────────────────────────────────────
#               2  6                     2  4                       2  2
# 067200000.0⋅H₀ ⋅L  + 2205840000000.0⋅H₀ ⋅L  - 100080000000000.0⋅H₀ ⋅L  + 1.839
#
#             5                   5                    3                     3
# 67567500.0⋅L ⋅v₀ + 207900000.0⋅L ⋅v₁ - 3984750000.0⋅L ⋅v₀ - 23100000000.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#         2                8                  6                    4
# 6e+15⋅H₀  + 207900000.0⋅L  - 46200000000.0⋅L  + 3690000000000.0⋅L  - 126000000
#
#                                             ⎞
# ₁ + 86625000000.0⋅L⋅v₀ + 495000000000.0⋅L⋅v₁⎠
# ──────────────────────────────────────────────
#           2
# 000000.0⋅L  + 1.75e+15
# d1 = ⎛           2  2                     2                 4                   2
# -⎝552960.0⋅H₀ ⋅L ⋅m⋅v₁ - 18432000.0⋅H₀ ⋅m⋅v₁ + 57600.0⋅L ⋅m⋅v₁ - 3840000.0⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                        2         8            6              4               2
#           18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L
#
#                       ⎞
# m⋅v₁ + 12800000.0⋅m⋅v₁⎠
# ────────────────────────
#
#  + 354400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 = ⎛           4  7                   4  5                     4  3
# -⎝349272.0⋅H₀ ⋅L ⋅v₁ - 99792000.0⋅H₀ ⋅L ⋅v₁ + 9258480000.0⋅H₀ ⋅L ⋅v₁ - 2772000
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                            349
#
#           4                   2  7                   2  7                    2
# 00000.0⋅H₀ ⋅L⋅v₁ - 436590.0⋅H₀ ⋅L ⋅v₀ + 18711000.0⋅H₀ ⋅L ⋅v₁ + 124740000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
#         4  8                4  6                   4  4                    4
# 272.0⋅H₀ ⋅L  - 99792000.0⋅H₀ ⋅L  + 10755360000.0⋅H₀ ⋅L  - 554400000000.0⋅H₀ ⋅L
#
#   5                     2  5                      2  3                       2
# ⋅L ⋅v₀ - 5266800000.0⋅H₀ ⋅L ⋅v₁ - 11573100000.0⋅H₀ ⋅L ⋅v₀ + 475230000000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
# 2                      4                2  8                  2  6
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 =         ⎛          4  5                  4  3                    4
# -1.03125⋅⎝42336.0⋅H₀ ⋅L ⋅v₁ - 6048000.0⋅H₀ ⋅L ⋅v₁ + 181440000.0⋅H₀ ⋅L⋅v₁ - 529
# ──────────────────────────────────────────────────────────────────────────────
#                             4  8                4  6                  4  4
#                   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 6
#
#        2  5                  2  5                  2  3                    2
# 20.0⋅H₀ ⋅L ⋅v₀ + 2268000.0⋅H₀ ⋅L ⋅v₁ + 7560000.0⋅H₀ ⋅L ⋅v₀ - 319200000.0⋅H₀ ⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                4  2                     4               2  8                 2
# 9300000000.0⋅H₀ ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀
#
# 3                    2                       2                 7
#  ⋅v₁ - 226800000.0⋅H₀ ⋅L⋅v₀ + 9240000000.0⋅H₀ ⋅L⋅v₁ - 11025.0⋅L ⋅v₀ + 2047500.
# ──────────────────────────────────────────────────────────────────────────────
#   6                   2  4                     2  2                      2
# ⋅L  + 68932500000.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6
#
#    5                 5                   3                   3
# 0⋅L ⋅v₀ + 6300000.0⋅L ⋅v₁ - 120750000.0⋅L ⋅v₀ - 700000000.0⋅L ⋅v₁ + 2625000000
# ──────────────────────────────────────────────────────────────────────────────
#           8                 6                   4                    2
# 496875.0⋅L  - 1443750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687
#
#                             ⎞
# .0⋅L⋅v₀ + 15000000000.0⋅L⋅v₁⎠
# ──────────────────────────────
#
# 500000000.0
# d1 =        ⎛        2  2                  2              4                2
# -1280.0⋅⎝432.0⋅H₀ ⋅L ⋅m⋅v₁ - 14400.0⋅H₀ ⋅m⋅v₁ + 45.0⋅L ⋅m⋅v₁ - 3000.0⋅L ⋅m⋅v₁
# ──────────────────────────────────────────────────────────────────────────────
#                    2         8            6              4               2
#       18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3
#
#               ⎞
# + 10000.0⋅m⋅v₁⎠
# ────────────────
#
# 54400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 = ⎛           4  7                   4  5                     4  3
# -⎝349272.0⋅H₀ ⋅L ⋅v₁ - 99792000.0⋅H₀ ⋅L ⋅v₁ + 9258480000.0⋅H₀ ⋅L ⋅v₁ - 2772000
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                            349
#
#           4                   2  7                   2  7                    2
# 00000.0⋅H₀ ⋅L⋅v₁ - 436590.0⋅H₀ ⋅L ⋅v₀ + 18711000.0⋅H₀ ⋅L ⋅v₁ + 124740000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
#         4  8                4  6                   4  4                    4
# 272.0⋅H₀ ⋅L  - 99792000.0⋅H₀ ⋅L  + 10755360000.0⋅H₀ ⋅L  - 554400000000.0⋅H₀ ⋅L
#
#   5                     2  5                      2  3                       2
# ⋅L ⋅v₀ - 5266800000.0⋅H₀ ⋅L ⋅v₁ - 11573100000.0⋅H₀ ⋅L ⋅v₀ + 475230000000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
# 2                      4                2  8                  2  6
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 =         ⎛          4  5                  4  3                    4
# -1.03125⋅⎝42336.0⋅H₀ ⋅L ⋅v₁ - 6048000.0⋅H₀ ⋅L ⋅v₁ + 181440000.0⋅H₀ ⋅L⋅v₁ - 529
# ──────────────────────────────────────────────────────────────────────────────
#                             4  8                4  6                  4  4
#                   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 6
#
#        2  5                  2  5                  2  3                    2
# 20.0⋅H₀ ⋅L ⋅v₀ + 2268000.0⋅H₀ ⋅L ⋅v₁ + 7560000.0⋅H₀ ⋅L ⋅v₀ - 319200000.0⋅H₀ ⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                4  2                     4               2  8                 2
# 9300000000.0⋅H₀ ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀
#
# 3                    2                       2                 7
#  ⋅v₁ - 226800000.0⋅H₀ ⋅L⋅v₀ + 9240000000.0⋅H₀ ⋅L⋅v₁ - 11025.0⋅L ⋅v₀ + 2047500.
# ──────────────────────────────────────────────────────────────────────────────
#   6                   2  4                     2  2                      2
# ⋅L  + 68932500000.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6
#
#    5                 5                   3                   3
# 0⋅L ⋅v₀ + 6300000.0⋅L ⋅v₁ - 120750000.0⋅L ⋅v₀ - 700000000.0⋅L ⋅v₁ + 2625000000
# ──────────────────────────────────────────────────────────────────────────────
#           8                 6                   4                    2
# 496875.0⋅L  - 1443750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687
#
#                             ⎞
# .0⋅L⋅v₀ + 15000000000.0⋅L⋅v₁⎠
# ──────────────────────────────
#
# 500000000.0
# d1 = ⎛           2  2                     2                 4                   2
# -⎝552960.0⋅H₀ ⋅L ⋅m⋅v₁ - 18432000.0⋅H₀ ⋅m⋅v₁ + 57600.0⋅L ⋅m⋅v₁ - 3840000.0⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                        2         8            6              4               2
#           18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L
#
#                       ⎞
# m⋅v₁ + 12800000.0⋅m⋅v₁⎠
# ────────────────────────
#
#  + 354400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 = ⎛           4  7                   4  5                     4  3
# -⎝349272.0⋅H₀ ⋅L ⋅v₁ - 99792000.0⋅H₀ ⋅L ⋅v₁ + 9258480000.0⋅H₀ ⋅L ⋅v₁ - 2772000
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                            349
#
#           4                   2  7                   2  7                    2
# 00000.0⋅H₀ ⋅L⋅v₁ - 436590.0⋅H₀ ⋅L ⋅v₀ + 18711000.0⋅H₀ ⋅L ⋅v₁ + 124740000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
#         4  8                4  6                   4  4                    4
# 272.0⋅H₀ ⋅L  - 99792000.0⋅H₀ ⋅L  + 10755360000.0⋅H₀ ⋅L  - 554400000000.0⋅H₀ ⋅L
#
#   5                     2  5                      2  3                       2
# ⋅L ⋅v₀ - 5266800000.0⋅H₀ ⋅L ⋅v₁ - 11573100000.0⋅H₀ ⋅L ⋅v₀ + 475230000000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
# 2                      4                2  8                  2  6
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 = ⎛            4  5                    4  3                     4
# -⎝1397088.0⋅H₀ ⋅L ⋅v₁ - 199584000.0⋅H₀ ⋅L ⋅v₁ + 5987520000.0⋅H₀ ⋅L⋅v₁ - 174636
# ──────────────────────────────────────────────────────────────────────────────
#                                    4  8                 4  6
#                        1397088.0⋅H₀ ⋅L  - 399168000.0⋅H₀ ⋅L  + 43021440000.0⋅H
#
#       2  5                   2  5                    2  3
# 0.0⋅H₀ ⋅L ⋅v₀ + 74844000.0⋅H₀ ⋅L ⋅v₁ + 249480000.0⋅H₀ ⋅L ⋅v₀ - 10533600000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#  4  4                     4  2                      4                2  8
# ₀ ⋅L  - 2217600000000.0⋅H₀ ⋅L  + 71280000000000.0⋅H₀  + 74844000.0⋅H₀ ⋅L  - 21
#
#  2  3                     2                         2                  7
# ₀ ⋅L ⋅v₁ - 7484400000.0⋅H₀ ⋅L⋅v₀ + 304920000000.0⋅H₀ ⋅L⋅v₁ - 363825.0⋅L ⋅v₀ +
# ──────────────────────────────────────────────────────────────────────────────
#               2  6                     2  4                       2  2
# 067200000.0⋅H₀ ⋅L  + 2205840000000.0⋅H₀ ⋅L  - 100080000000000.0⋅H₀ ⋅L  + 1.839
#
#             5                   5                    3                     3
# 67567500.0⋅L ⋅v₀ + 207900000.0⋅L ⋅v₁ - 3984750000.0⋅L ⋅v₀ - 23100000000.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#         2                8                  6                    4
# 6e+15⋅H₀  + 207900000.0⋅L  - 46200000000.0⋅L  + 3690000000000.0⋅L  - 126000000
#
#                                             ⎞
# ₁ + 86625000000.0⋅L⋅v₀ + 495000000000.0⋅L⋅v₁⎠
# ──────────────────────────────────────────────
#           2
# 000000.0⋅L  + 1.75e+15
# d1 =        ⎛        2  2                  2              4                2
# -1280.0⋅⎝432.0⋅H₀ ⋅L ⋅m⋅v₁ - 14400.0⋅H₀ ⋅m⋅v₁ + 45.0⋅L ⋅m⋅v₁ - 3000.0⋅L ⋅m⋅v₁
# ──────────────────────────────────────────────────────────────────────────────
#                    2         8            6              4               2
#       18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3
#
#               ⎞
# + 10000.0⋅m⋅v₁⎠
# ────────────────
#
# 54400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 = ⎛           4  7                   4  5                     4  3
# -⎝349272.0⋅H₀ ⋅L ⋅v₁ - 99792000.0⋅H₀ ⋅L ⋅v₁ + 9258480000.0⋅H₀ ⋅L ⋅v₁ - 2772000
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                            349
#
#           4                   2  7                   2  7                    2
# 00000.0⋅H₀ ⋅L⋅v₁ - 436590.0⋅H₀ ⋅L ⋅v₀ + 18711000.0⋅H₀ ⋅L ⋅v₁ + 124740000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
#         4  8                4  6                   4  4                    4
# 272.0⋅H₀ ⋅L  - 99792000.0⋅H₀ ⋅L  + 10755360000.0⋅H₀ ⋅L  - 554400000000.0⋅H₀ ⋅L
#
#   5                     2  5                      2  3                       2
# ⋅L ⋅v₀ - 5266800000.0⋅H₀ ⋅L ⋅v₁ - 11573100000.0⋅H₀ ⋅L ⋅v₀ + 475230000000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
# 2                      4                2  8                  2  6
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                         ⎛ 6             4              2   ⎞
#                    -63.0⋅⎝L ⋅v₁ - 120.0⋅L ⋅v₁ + 2000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 = ⎛            4  5                    4  3                     4
# -⎝1397088.0⋅H₀ ⋅L ⋅v₁ - 199584000.0⋅H₀ ⋅L ⋅v₁ + 5987520000.0⋅H₀ ⋅L⋅v₁ - 174636
# ──────────────────────────────────────────────────────────────────────────────
#                                    4  8                 4  6
#                        1397088.0⋅H₀ ⋅L  - 399168000.0⋅H₀ ⋅L  + 43021440000.0⋅H
#
#       2  5                   2  5                    2  3
# 0.0⋅H₀ ⋅L ⋅v₀ + 74844000.0⋅H₀ ⋅L ⋅v₁ + 249480000.0⋅H₀ ⋅L ⋅v₀ - 10533600000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#  4  4                     4  2                      4                2  8
# ₀ ⋅L  - 2217600000000.0⋅H₀ ⋅L  + 71280000000000.0⋅H₀  + 74844000.0⋅H₀ ⋅L  - 21
#
#  2  3                     2                         2                  7
# ₀ ⋅L ⋅v₁ - 7484400000.0⋅H₀ ⋅L⋅v₀ + 304920000000.0⋅H₀ ⋅L⋅v₁ - 363825.0⋅L ⋅v₀ +
# ──────────────────────────────────────────────────────────────────────────────
#               2  6                     2  4                       2  2
# 067200000.0⋅H₀ ⋅L  + 2205840000000.0⋅H₀ ⋅L  - 100080000000000.0⋅H₀ ⋅L  + 1.839
#
#             5                   5                    3                     3
# 67567500.0⋅L ⋅v₀ + 207900000.0⋅L ⋅v₁ - 3984750000.0⋅L ⋅v₀ - 23100000000.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#         2                8                  6                    4
# 6e+15⋅H₀  + 207900000.0⋅L  - 46200000000.0⋅L  + 3690000000000.0⋅L  - 126000000
#
#                                             ⎞
# ₁ + 86625000000.0⋅L⋅v₀ + 495000000000.0⋅L⋅v₁⎠
# ──────────────────────────────────────────────
#           2
# 000000.0⋅L  + 1.75e+15
# d1 = ⎛           2  2                     2                 4                   2
# -⎝552960.0⋅H₀ ⋅L ⋅m⋅v₁ - 18432000.0⋅H₀ ⋅m⋅v₁ + 57600.0⋅L ⋅m⋅v₁ - 3840000.0⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                        2         8            6              4               2
#           18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L
#
#                       ⎞
# m⋅v₁ + 12800000.0⋅m⋅v₁⎠
# ────────────────────────
#
#  + 354400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =                ⎛ 8             6               4                2   ⎞
#           -63.0⋅⎝L ⋅v₁ - 240.0⋅L ⋅v₁ + 16400.0⋅L ⋅v₁ - 240000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 =       ⎛           4  7                   4  5                     4  3
# -0.375⋅⎝116424.0⋅H₀ ⋅L ⋅v₁ - 33264000.0⋅H₀ ⋅L ⋅v₁ + 3086160000.0⋅H₀ ⋅L ⋅v₁ - 9
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                4                   2  7                  2  7
# 2400000000.0⋅H₀ ⋅L⋅v₁ - 145530.0⋅H₀ ⋅L ⋅v₀ + 6237000.0⋅H₀ ⋅L ⋅v₁ + 41580000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             4  8                4  6                  4  4                   4
#   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 69300000000.0⋅H₀
#
#   2  5                     2  5                     2  3
# H₀ ⋅L ⋅v₀ - 1755600000.0⋅H₀ ⋅L ⋅v₁ - 3857700000.0⋅H₀ ⋅L ⋅v₀ + 158410000000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#   2                     4               2  8                 2  6
# ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀ ⋅L  + 6893250000
#
#  2  3                       2                          2                   7
# ₀ ⋅L ⋅v₁ + 115500000000.0⋅H₀ ⋅L⋅v₀ - 4170000000000.0⋅H₀ ⋅L⋅v₁ + 1299375.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#       2  4                     2  2                      2              8
# 0.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6496875.0⋅L  - 14
#
#                 7                   5                    5
# ₀ + 17325000.0⋅L ⋅v₁ - 274312500.0⋅L ⋅v₀ - 3850000000.0⋅L ⋅v₁ + 19031250000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#             6                   4                    2
# 43750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687500000000.0
#
#  3                      3                                                ⎞
# L ⋅v₀ + 266250000000.0⋅L ⋅v₁ - 459375000000.0⋅L⋅v₀ - 5250000000000.0⋅L⋅v₁⎠
# ───────────────────────────────────────────────────────────────────────────
#
#
# a2 =0
# a3 =                   ⎛      6              4                2   ⎞
#                   -⎝63.0⋅L ⋅v₁ - 7560.0⋅L ⋅v₁ + 126000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# ...
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                   ⎛      6              4                2   ⎞
#                   -⎝63.0⋅L ⋅v₁ - 7560.0⋅L ⋅v₁ + 126000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 =         ⎛          4  5                  4  3                    4
# -1.03125⋅⎝42336.0⋅H₀ ⋅L ⋅v₁ - 6048000.0⋅H₀ ⋅L ⋅v₁ + 181440000.0⋅H₀ ⋅L⋅v₁ - 529
# ──────────────────────────────────────────────────────────────────────────────
#                             4  8                4  6                  4  4
#                   43659.0⋅H₀ ⋅L  - 12474000.0⋅H₀ ⋅L  + 1344420000.0⋅H₀ ⋅L  - 6
#
#        2  5                  2  5                  2  3                    2
# 20.0⋅H₀ ⋅L ⋅v₀ + 2268000.0⋅H₀ ⋅L ⋅v₁ + 7560000.0⋅H₀ ⋅L ⋅v₀ - 319200000.0⋅H₀ ⋅L
# ──────────────────────────────────────────────────────────────────────────────
#                4  2                     4               2  8                 2
# 9300000000.0⋅H₀ ⋅L  + 2227500000000.0⋅H₀  + 2338875.0⋅H₀ ⋅L  - 658350000.0⋅H₀
#
# 3                    2                       2                 7
#  ⋅v₁ - 226800000.0⋅H₀ ⋅L⋅v₀ + 9240000000.0⋅H₀ ⋅L⋅v₁ - 11025.0⋅L ⋅v₀ + 2047500.
# ──────────────────────────────────────────────────────────────────────────────
#   6                   2  4                     2  2                      2
# ⋅L  + 68932500000.0⋅H₀ ⋅L  - 3127500000000.0⋅H₀ ⋅L  + 57487500000000.0⋅H₀  + 6
#
#    5                 5                   3                   3
# 0⋅L ⋅v₀ + 6300000.0⋅L ⋅v₁ - 120750000.0⋅L ⋅v₀ - 700000000.0⋅L ⋅v₁ + 2625000000
# ──────────────────────────────────────────────────────────────────────────────
#           8                 6                   4                    2
# 496875.0⋅L  - 1443750000.0⋅L  + 115312500000.0⋅L  - 3937500000000.0⋅L  + 54687
#
#                             ⎞
# .0⋅L⋅v₀ + 15000000000.0⋅L⋅v₁⎠
# ──────────────────────────────
#
# 500000000.0
# d1 = ⎛           2  2                     2                 4                   2
# -⎝552960.0⋅H₀ ⋅L ⋅m⋅v₁ - 18432000.0⋅H₀ ⋅m⋅v₁ + 57600.0⋅L ⋅m⋅v₁ - 3840000.0⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                        2         8            6              4               2
#           18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L
#
#                       ⎞
# m⋅v₁ + 12800000.0⋅m⋅v₁⎠
# ────────────────────────
#
#  + 354400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =        ⎛      8               6                 4                  2   ⎞
#        -⎝63.0⋅L ⋅v₁ - 15120.0⋅L ⋅v₁ + 1033200.0⋅L ⋅v₁ - 15120000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 = ⎛           4  7                   4  5                     4  3
# -⎝349272.0⋅H₀ ⋅L ⋅v₁ - 99792000.0⋅H₀ ⋅L ⋅v₁ + 9258480000.0⋅H₀ ⋅L ⋅v₁ - 2772000
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                            349
#
#           4                   2  7                   2  7                    2
# 00000.0⋅H₀ ⋅L⋅v₁ - 436590.0⋅H₀ ⋅L ⋅v₀ + 18711000.0⋅H₀ ⋅L ⋅v₁ + 124740000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
#         4  8                4  6                   4  4                    4
# 272.0⋅H₀ ⋅L  - 99792000.0⋅H₀ ⋅L  + 10755360000.0⋅H₀ ⋅L  - 554400000000.0⋅H₀ ⋅L
#
#   5                     2  5                      2  3                       2
# ⋅L ⋅v₀ - 5266800000.0⋅H₀ ⋅L ⋅v₁ - 11573100000.0⋅H₀ ⋅L ⋅v₀ + 475230000000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
# 2                      4                2  8                  2  6
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                   ⎛      6              4                2   ⎞
#                   -⎝63.0⋅L ⋅v₁ - 7560.0⋅L ⋅v₁ + 126000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 = ⎛            4  5                    4  3                     4
# -⎝1397088.0⋅H₀ ⋅L ⋅v₁ - 199584000.0⋅H₀ ⋅L ⋅v₁ + 5987520000.0⋅H₀ ⋅L⋅v₁ - 174636
# ──────────────────────────────────────────────────────────────────────────────
#                                    4  8                 4  6
#                        1397088.0⋅H₀ ⋅L  - 399168000.0⋅H₀ ⋅L  + 43021440000.0⋅H
#
#       2  5                   2  5                    2  3
# 0.0⋅H₀ ⋅L ⋅v₀ + 74844000.0⋅H₀ ⋅L ⋅v₁ + 249480000.0⋅H₀ ⋅L ⋅v₀ - 10533600000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#  4  4                     4  2                      4                2  8
# ₀ ⋅L  - 2217600000000.0⋅H₀ ⋅L  + 71280000000000.0⋅H₀  + 74844000.0⋅H₀ ⋅L  - 21
#
#  2  3                     2                         2                  7
# ₀ ⋅L ⋅v₁ - 7484400000.0⋅H₀ ⋅L⋅v₀ + 304920000000.0⋅H₀ ⋅L⋅v₁ - 363825.0⋅L ⋅v₀ +
# ──────────────────────────────────────────────────────────────────────────────
#               2  6                     2  4                       2  2
# 067200000.0⋅H₀ ⋅L  + 2205840000000.0⋅H₀ ⋅L  - 100080000000000.0⋅H₀ ⋅L  + 1.839
#
#             5                   5                    3                     3
# 67567500.0⋅L ⋅v₀ + 207900000.0⋅L ⋅v₁ - 3984750000.0⋅L ⋅v₀ - 23100000000.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#         2                8                  6                    4
# 6e+15⋅H₀  + 207900000.0⋅L  - 46200000000.0⋅L  + 3690000000000.0⋅L  - 126000000
#
#                                             ⎞
# ₁ + 86625000000.0⋅L⋅v₀ + 495000000000.0⋅L⋅v₁⎠
# ──────────────────────────────────────────────
#           2
# 000000.0⋅L  + 1.75e+15
# d1 =        ⎛        2  2                  2              4                2
# -1280.0⋅⎝432.0⋅H₀ ⋅L ⋅m⋅v₁ - 14400.0⋅H₀ ⋅m⋅v₁ + 45.0⋅L ⋅m⋅v₁ - 3000.0⋅L ⋅m⋅v₁
# ──────────────────────────────────────────────────────────────────────────────
#                    2         8            6              4               2
#       18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3
#
#               ⎞
# + 10000.0⋅m⋅v₁⎠
# ────────────────
#
# 54400000.0
# d2 =d₂
# ==================================================
# New solution:
# a0 =        ⎛      8               6                 4                  2   ⎞
#        -⎝63.0⋅L ⋅v₁ - 15120.0⋅L ⋅v₁ + 1033200.0⋅L ⋅v₁ - 15120000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a1 = ⎛           4  7                   4  5                     4  3
# -⎝349272.0⋅H₀ ⋅L ⋅v₁ - 99792000.0⋅H₀ ⋅L ⋅v₁ + 9258480000.0⋅H₀ ⋅L ⋅v₁ - 2772000
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                            349
#
#           4                   2  7                   2  7                    2
# 00000.0⋅H₀ ⋅L⋅v₁ - 436590.0⋅H₀ ⋅L ⋅v₀ + 18711000.0⋅H₀ ⋅L ⋅v₁ + 124740000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
#         4  8                4  6                   4  4                    4
# 272.0⋅H₀ ⋅L  - 99792000.0⋅H₀ ⋅L  + 10755360000.0⋅H₀ ⋅L  - 554400000000.0⋅H₀ ⋅L
#
#   5                     2  5                      2  3                       2
# ⋅L ⋅v₀ - 5266800000.0⋅H₀ ⋅L ⋅v₁ - 11573100000.0⋅H₀ ⋅L ⋅v₀ + 475230000000.0⋅H₀
# ──────────────────────────────────────────────────────────────────────────────
# 2                      4                2  8                  2  6
#   + 17820000000000.0⋅H₀  + 18711000.0⋅H₀ ⋅L  - 5266800000.0⋅H₀ ⋅L  + 551460000
#
#   3                       2                           2                   7
# ⋅L ⋅v₁ + 346500000000.0⋅H₀ ⋅L⋅v₀ - 12510000000000.0⋅H₀ ⋅L⋅v₁ + 3898125.0⋅L ⋅v₀
# ──────────────────────────────────────────────────────────────────────────────
#         2  4                      2  2                       2               8
# 000.0⋅H₀ ⋅L  - 25020000000000.0⋅H₀ ⋅L  + 459900000000000.0⋅H₀  + 51975000.0⋅L
#
#                7                   5                     5
#  + 51975000.0⋅L ⋅v₁ - 822937500.0⋅L ⋅v₀ - 11550000000.0⋅L ⋅v₁ + 57093750000.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#                   6                   4                     2
#  - 11550000000.0⋅L  + 922500000000.0⋅L  - 31500000000000.0⋅L  + 43750000000000
#
#  3                      3                                                  ⎞
# L ⋅v₀ + 798750000000.0⋅L ⋅v₁ - 1378125000000.0⋅L⋅v₀ - 15750000000000.0⋅L⋅v₁⎠
# ─────────────────────────────────────────────────────────────────────────────
#
# 0.0
# a2 =0
# a3 =                   ⎛      6              4                2   ⎞
#                   -⎝63.0⋅L ⋅v₁ - 7560.0⋅L ⋅v₁ + 126000.0⋅L ⋅v₁⎠
# ──────────────────────────────────────────────────────────────────────────────
#              2         8            6              4               2
# 18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L  + 3544000
#
#
#
# ────
#
# 00.0
# a4 = ⎛            4  5                    4  3                     4
# -⎝1397088.0⋅H₀ ⋅L ⋅v₁ - 199584000.0⋅H₀ ⋅L ⋅v₁ + 5987520000.0⋅H₀ ⋅L⋅v₁ - 174636
# ──────────────────────────────────────────────────────────────────────────────
#                                    4  8                 4  6
#                        1397088.0⋅H₀ ⋅L  - 399168000.0⋅H₀ ⋅L  + 43021440000.0⋅H
#
#       2  5                   2  5                    2  3
# 0.0⋅H₀ ⋅L ⋅v₀ + 74844000.0⋅H₀ ⋅L ⋅v₁ + 249480000.0⋅H₀ ⋅L ⋅v₀ - 10533600000.0⋅H
# ──────────────────────────────────────────────────────────────────────────────
#  4  4                     4  2                      4                2  8
# ₀ ⋅L  - 2217600000000.0⋅H₀ ⋅L  + 71280000000000.0⋅H₀  + 74844000.0⋅H₀ ⋅L  - 21
#
#  2  3                     2                         2                  7
# ₀ ⋅L ⋅v₁ - 7484400000.0⋅H₀ ⋅L⋅v₀ + 304920000000.0⋅H₀ ⋅L⋅v₁ - 363825.0⋅L ⋅v₀ +
# ──────────────────────────────────────────────────────────────────────────────
#               2  6                     2  4                       2  2
# 067200000.0⋅H₀ ⋅L  + 2205840000000.0⋅H₀ ⋅L  - 100080000000000.0⋅H₀ ⋅L  + 1.839
#
#             5                   5                    3                     3
# 67567500.0⋅L ⋅v₀ + 207900000.0⋅L ⋅v₁ - 3984750000.0⋅L ⋅v₀ - 23100000000.0⋅L ⋅v
# ──────────────────────────────────────────────────────────────────────────────
#         2                8                  6                    4
# 6e+15⋅H₀  + 207900000.0⋅L  - 46200000000.0⋅L  + 3690000000000.0⋅L  - 126000000
#
#                                             ⎞
# ₁ + 86625000000.0⋅L⋅v₀ + 495000000000.0⋅L⋅v₁⎠
# ──────────────────────────────────────────────
#           2
# 000000.0⋅L  + 1.75e+15
# d1 = ⎛           2  2                     2                 4                   2
# -⎝552960.0⋅H₀ ⋅L ⋅m⋅v₁ - 18432000.0⋅H₀ ⋅m⋅v₁ + 57600.0⋅L ⋅m⋅v₁ - 3840000.0⋅L ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                        2         8            6              4               2
#           18432000.0⋅H₀  + 63.0⋅L  - 15120.0⋅L  + 1159200.0⋅L  - 30240000.0⋅L
#
#                       ⎞
# m⋅v₁ + 12800000.0⋅m⋅v₁⎠
# ────────────────────────
#
#  + 354400000.0
# d2 =d₂
# ==================================================
# 1. Building plot
# ====================================================================================================
# vx =  v0*(1 - x/L) + v1*(1 + x/L)*(H0**2 - y**2) + (1 - x**2/L**2)*(H0**2 - y**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3)
# vx1 =  -x/5 + 4.8*(x/10 + 1)*(-y**2 + 1) + (-x**2/100 + 1)*(-0.0130980101608806*x**3 - 0.328640982218459*x)*(-y**2 + 1) + 2
# ----------------------------------------------------------------------------------------------------
# vx1 =  0.28*x + (-x**2/100 + 1)*(-0.0130980101608806*x**3 - 0.328640982218459*x) + 6.8
# ====================================================================================================

# %%
if len(result) == 0:
    print('No solutions!')
else:
    print('2. Building plot')
    vy1 = substitute(vy, variables, result[0])
    print('=' * 100)
    vy1 = substitute(vy1, [v0,v1,  H0, L], [v0_,v1_, H0_, L_])
    print("vy = ", vy)
    print("vy1 = ", vy1)
    print('-' * 100)
    vy1 = substitute(vy1, [x], [0])
    print("vy1 = ", vy1)
    print(nonlinsolve([vy1], [y]))
    print(substitute(vy1, [y], [0]))
    p2 = sympy.plotting.plot(vy1, xlim=(-1, (1 + 0.1)), ylim=(-(0.3), (0.3)), ylabel='vy')
# Out:
# 2. Building plot
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5e4bd7ea0f29> in <module>()
#       3 else:
#       4     print('2. Building plot')
# ----> 5     vy1 = substitute(vy, variables, result[0])
#       6     print('=' * 100)
#       7     vy1 = substitute(vy1, [v0,v1,  H0, L], [v0_,v1_, H0_, L_])
#
# /home/freemahn/Projects/diploma/lib.py in substitute(func, vars, vals)
#      11     for v in vars:
#      12         val = vals[i]
# ---> 13         f = f.subs(v, val)
#      14         i = i + 1
#      15     return f
#
# AttributeError: 'int' object has no attribute 'subs'
