# %%
from sympy import *;import sympy;import random;from sympy.core.symbol import symbols;from sympy.solvers.solveset import nonlinsolve
from lib import *
init_printing()
a, b, c, d, d1, d2, d3 = symbols('a, b, c, d, d1, d2, d3')
a0, a1,a2, a3,a4, a5,a6,a7,a8,a9,a10, b1 = symbols('a0, a1, a2, a3,a4,a5,a6,a7,a8, a9, a10, b1')
m, L, H0 = symbols('m, L, H0');x, y = symbols('x, y');v0, v1 = symbols('v0, v1')

# %%
H0_, L_ = 1, 10;m_, v0_ = 1, 2;v1_ = 12/5*v0_  
H = H0 -  0.1*(2* x / L_  - 1) ** 2
Tx = a0 + a1 * x + a2*y + a3 * x ** 2 + a4 * x **3
vx = v0 * (1- x/L) + v1 *(H**2-y**2)*(x/L)  + (1-x**2/L**2)*(H ** 2 - y ** 2) * Tx
p = d1 * x + d2 * x ** 2
print("vx=", vx);print("p=", p)
# checking profiles
print("vx(-L, y) =", substitute(vx, [x], [-L]));print("vx(L, y) =", substitute(vx, [x], [L]))
print("H(-L) =", substitute(H ** 2, [x], [-L]));print("H(L) =", substitute(H ** 2, [x], [L]))
# Out:
# vx= v0*(1 - x/L) + (1 - x**2/L**2)*(-y**2 + (H0 - 0.1*(x/5 - 1)**2)**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3) + v1*x*(-y**2 + (H0 - 0.1*(x/5 - 1)**2)**2)/L
# p= d1*x + d2*x**2
# vx(-L, y) = 2*v0 - v1*(-y**2 + (H0 - 0.1*(-L/5 - 1)**2)**2)
# vx(L, y) = v1*(-y**2 + (H0 - 0.1*(L/5 - 1)**2)**2)
# H(-L) = (H0 - 0.1*(-L/5 - 1)**2)**2
# H(L) = (H0 - 0.1*(L/5 - 1)**2)**2

# %%
dxvx = diff(vx, x);dyvy = - dxvx;print("dyvy=", dyvy);vy = integrate(dyvy, y);print("vy=", vy);print('='*50)
# Out:
# dyvy= -(1 - x**2/L**2)*(H0 - 0.1*(x/5 - 1)**2)*(-0.016*x + 0.08)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3) - (1 - x**2/L**2)*(-y**2 + (H0 - 0.1*(x/5 - 1)**2)**2)*(a1 + 2*a3*x + 3*a4*x**2) + v0/L - v1*x*(H0 - 0.1*(x/5 - 1)**2)*(-0.016*x + 0.08)/L - v1*(-y**2 + (H0 - 0.1*(x/5 - 1)**2)**2)/L + 2*x*(-y**2 + (H0 - 0.1*(x/5 - 1)**2)**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3)/L**2
# vy= -0.5*a2*x*y**4/L**2 + 0.333333333333333*y**3*(1.0*L**2*a1 + 2.0*L**2*a3*x + 3.0*L**2*a4*x**2 + 1.0*L*v1 - 2.0*a0*x - 3.0*a1*x**2 - 4.0*a3*x**3 - 5.0*a4*x**4)/L**2 + 0.5*y**2*(2.0*H0**2*a2*x + 0.016*H0*L**2*a2*x - 0.08*H0*L**2*a2 - 0.032*H0*a2*x**3 + 0.24*H0*a2*x**2 - 0.4*H0*a2*x - 6.4e-5*L**2*a2*x**3 + 0.00096*L**2*a2*x**2 - 0.0048*L**2*a2*x + 0.008*L**2*a2 + 9.6e-5*a2*x**5 - 0.0016*a2*x**4 + 0.0096*a2*x**3 - 0.024*a2*x**2 + 0.02*a2*x)/L**2 + 1.0*y*(-1.0*H0**2*L**2*a1 - 2.0*H0**2*L**2*a3*x - 3.0*H0**2*L**2*a4*x**2 - 1.0*H0**2*L*v1 + 2.0*H0**2*a0*x + 3.0*H0**2*a1*x**2 + 4.0*H0**2*a3*x**3 + 5.0*H0**2*a4*x**4 + 0.016*H0*L**2*a0*x - 0.08*H0*L**2*a0 + 0.024*H0*L**2*a1*x**2 - 0.16*H0*L**2*a1*x + 0.2*H0*L**2*a1 + 0.032*H0*L**2*a3*x**3 - 0.24*H0*L**2*a3*x**2 + 0.4*H0*L**2*a3*x + 0.04*H0*L**2*a4*x**4 - 0.32*H0*L**2*a4*x**3 + 0.6*H0*L**2*a4*x**2 + 0.024*H0*L*v1*x**2 - 0.16*H0*L*v1*x + 0.2*H0*L*v1 - 0.032*H0*a0*x**3 + 0.24*H0*a0*x**2 - 0.4*H0*a0*x - 0.04*H0*a1*x**4 + 0.32*H0*a1*x**3 - 0.6*H0*a1*x**2 - 0.048*H0*a3*x**5 + 0.4*H0*a3*x**4 - 0.8*H0*a3*x**3 - 0.056*H0*a4*x**6 + 0.48*H0*a4*x**5 - 1.0*H0*a4*x**4 - 6.4e-5*L**2*a0*x**3 + 0.00096*L**2*a0*x**2 - 0.0048*L**2*a0*x + 0.008*L**2*a0 - 8.0e-5*L**2*a1*x**4 + 0.00128*L**2*a1*x**3 - 0.0072*L**2*a1*x**2 + 0.016*L**2*a1*x - 0.01*L**2*a1 - 9.6e-5*L**2*a3*x**5 + 0.0016*L**2*a3*x**4 - 0.0096*L**2*a3*x**3 + 0.024*L**2*a3*x**2 - 0.02*L**2*a3*x - 0.000112*L**2*a4*x**6 + 0.00192*L**2*a4*x**5 - 0.012*L**2*a4*x**4 + 0.032*L**2*a4*x**3 - 0.03*L**2*a4*x**2 + 1.0*L*v0 - 8.0e-5*L*v1*x**4 + 0.00128*L*v1*x**3 - 0.0072*L*v1*x**2 + 0.016*L*v1*x - 0.01*L*v1 + 9.6e-5*a0*x**5 - 0.0016*a0*x**4 + 0.0096*a0*x**3 - 0.024*a0*x**2 + 0.02*a0*x + 0.000112*a1*x**6 - 0.00192*a1*x**5 + 0.012*a1*x**4 - 0.032*a1*x**3 + 0.03*a1*x**2 + 0.000128*a3*x**7 - 0.00224*a3*x**6 + 0.0144*a3*x**5 - 0.04*a3*x**4 + 0.04*a3*x**3 + 0.000144*a4*x**8 - 0.00256*a4*x**7 + 0.0168*a4*x**6 - 0.048*a4*x**5 + 0.05*a4*x**4)/L**2
# ==================================================

# %%
pxx = -p * 1 + m * (diff(vx, x) + diff(vx, x));pxy = -p * 0 + m * (diff(vx, y) + diff(vy, x));pyy = -p * 1 + m * (diff(vy, y) + diff(vy, y))
p2ij = pxx ** 2 + 2 * pxy ** 2 + pyy ** 2;f = p2ij - 2 * (p ** 2) 
f = substitute(f, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
print("f=", f);   print('1. Integrating ...')
fx = integrate(f, (y, -H, H)) 
fx = substitute(fx, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
print("fx=", fx); print('2. Integrating ...')
g = integrate(fx, (x, -L_, L_))
g = substitute(g, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
print('g=', end='')
pprint(g)
print('='*50)
# Out:
# f= -2*(d1*x + d2*x**2)**2 + 2*(-0.005*a2*y**4 + a2*(-x**2/100 + 1)*(-y**2 + (-0.1*(x/5 - 1)**2 + 1)**2) - 0.96*x*y + 0.00333333333333333*y**3*(-2.0*a0 - 6.0*a1*x - 12.0*a3*x**2 + 200.0*a3 - 20.0*a4*x**3 + 600.0*a4*x) + 0.005*y**2*(0.00048*a2*x**4 - 0.0064*a2*x**3 - 0.0864*a2*x**2 + 0.624*a2*x + 2.74*a2) - 2*y*(-x**2/100 + 1)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3) + 0.01*y*(0.00048*a0*x**4 - 0.0064*a0*x**3 - 0.0864*a0*x**2 + 0.624*a0*x + 2.74*a0 + 0.000672*a1*x**5 - 0.0096*a1*x**4 - 0.144*a1*x**3 + 1.248*a1*x**2 + 8.22*a1*x - 14.4*a1 + 0.000896*a3*x**6 - 0.01344*a3*x**5 - 0.216*a3*x**4 + 2.08*a3*x**3 + 16.44*a3*x**2 - 43.2*a3*x - 162.0*a3 + 0.001152*a4*x**7 - 0.01792*a4*x**6 - 0.3024*a4*x**5 + 3.12*a4*x**4 + 27.4*a4*x**3 - 86.4*a4*x**2 - 486.0*a4*x - 0.01536*x**3 + 0.18432*x**2 + 1.6128*x - 6.912))**2 + (-d1*x - d2*x**2 + 0.96*x*(-0.016*x + 0.08)*(-0.1*(x/5 - 1)**2 + 1) - x*(-y**2 + (-0.1*(x/5 - 1)**2 + 1)**2)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3)/25 - 0.96*y**2 + 2*(-0.016*x + 0.08)*(-x**2/100 + 1)*(-0.1*(x/5 - 1)**2 + 1)*(a0 + a1*x + a2*y + a3*x**2 + a4*x**3) + 2*(-x**2/100 + 1)*(-y**2 + (-0.1*(x/5 - 1)**2 + 1)**2)*(a1 + 2*a3*x + 3*a4*x**2) + 0.96*(-0.1*(x/5 - 1)**2 + 1)**2 - 2/5)**2 + (1.92e-6*a0*x**5 - 3.2e-5*a0*x**4 - 0.000576*a0*x**3 + 0.00624*a0*x**2 + 0.0548*a0*x - 0.144*a0 + 2.24e-6*a1*x**6 - 3.84e-5*a1*x**5 - 0.00072*a1*x**4 + 0.00832*a1*x**3 + 0.0822*a1*x**2 - 0.288*a1*x - 1.62*a1 - 0.04*a2*x*y**3 + 2.56e-6*a3*x**7 - 4.48e-5*a3*x**6 - 0.000864*a3*x**5 + 0.0104*a3*x**4 + 0.1096*a3*x**3 - 0.432*a3*x**2 - 3.24*a3*x + 2.88e-6*a4*x**8 - 5.12e-5*a4*x**7 - 0.001008*a4*x**6 + 0.01248*a4*x**5 + 0.137*a4*x**4 - 0.576*a4*x**3 - 4.86*a4*x**2 - d1*x - d2*x**2 - 7.68e-5*x**4 + 0.0012288*x**3 + 0.016128*x**2 - 0.13824*x + 0.02*y**2*(-2.0*a0*x - 3.0*a1*x**2 + 100.0*a1 - 4.0*a3*x**3 + 200.0*a3*x - 5.0*a4*x**4 + 300.0*a4*x**2 + 48.0) + 0.02*y*(9.6e-5*a2*x**5 - 0.0016*a2*x**4 - 0.0288*a2*x**3 + 0.312*a2*x**2 + 2.74*a2*x - 7.2*a2) - 0.3776)**2
# 1. Integrating ...
# fx= 5.55555555555556e-6*a2**2*(-0.1*(x/5 - 1)**2 + 1)**9 - 5.55555555555556e-6*a2**2*(0.1*(x/5 - 1)**2 - 1)**9 + (-0.1*(x/5 - 1)**2 + 1)**8*(1.66666666666667e-5*a0*a2 + 5.0e-5*a1*a2*x + 0.0001*a2*a3*x**2 - 0.00166666666666667*a2*a3 + 0.000166666666666667*a2*a4*x**3 - 0.005*a2*a4*x) + (-0.1*(x/5 - 1)**2 + 1)**7*(1.26984126984127e-5*a0**2 + 7.61904761904762e-5*a0*a1*x + 0.000152380952380952*a0*a3*x**2 - 0.00253968253968254*a0*a3 + 0.000253968253968254*a0*a4*x**3 - 0.00761904761904762*a0*a4*x + 0.000114285714285714*a1**2*x**2 + 0.000457142857142857*a1*a3*x**3 - 0.00761904761904762*a1*a3*x + 0.000761904761904762*a1*a4*x**4 - 0.0228571428571429*a1*a4*x**2 - 6.85714285714286e-9*a2**2*x**4 + 9.14285714285714e-8*a2**2*x**3 + 0.000372662857142857*a2**2*x**2 - 8.91428571428572e-6*a2**2*x + 0.00853228571428571*a2**2 + 0.000457142857142857*a3**2*x**4 - 0.0152380952380952*a3**2*x**2 + 0.126984126984127*a3**2 + 0.00152380952380952*a3*a4*x**5 - 0.0711111111111111*a3*a4*x**3 + 0.761904761904762*a3*a4*x + 0.00126984126984127*a4**2*x**6 - 0.0761904761904762*a4**2*x**4 + 1.14285714285714*a4**2*x**2) + (-0.1*(x/5 - 1)**2 + 1)**6*(-2.66666666666667e-8*a0*a2*x**4 + 3.55555555555556e-7*a0*a2*x**3 + 0.000871466666666667*a0*a2*x**2 - 3.46666666666667e-5*a0*a2*x + 0.0198477777777778*a0*a2 - 5.44e-8*a1*a2*x**5 + 7.46666666666667e-7*a1*a2*x**4 + 0.00114389333333333*a1*a2*x**3 - 8.32e-5*a1*a2*x**2 - 0.00712333333333334*a1*a2*x + 0.00048*a1*a2 - 9.38666666666667e-8*a2*a3*x**6 + 1.30133333333333e-6*a2*a3*x**5 + 0.00128645333333333*a2*a3*x**4 - 0.000166755555555556*a2*a3*x**3 - 0.00777200000000001*a2*a3*x**2 + 0.00282666666666667*a2*a3*x - 1.32184444444444*a2*a3 - 1.45066666666667e-7*a2*a4*x**7 + 2.01955555555556e-6*a2*a4*x**6 + 0.00129914666666667*a2*a4*x**5 - 0.000285333333333333*a2*a4*x**4 + 0.0179017777777778*a2*a4*x**3 + 0.00704*a2*a4*x**2 - 3.96553333333333*a2*a4*x + 5.12e-7*a2*x**3 - 6.144e-6*a2*x**2 - 0.02245376*a2*x + 0.0002304*a2) + (-0.1*(x/5 - 1)**2 + 1)**5*(-2.56e-8*a0**2*x**4 + 3.41333333333333e-7*a0**2*x**3 + 0.000537941333333333*a0**2*x**2 - 3.328e-5*a0**2*x + 0.0105205333333333*a0**2 - 1.1264e-7*a0*a1*x**5 + 1.536e-6*a0*a1*x**4 + 0.00151483733333333*a0*a1*x**3 - 0.0001664*a0*a1*x**2 - 0.0222101333333333*a0*a1*x + 0.000768*a0*a1 - 2.01386666666667e-7*a0*a3*x**6 + 2.7648e-6*a0*a3*x**5 + 0.00185506133333333*a0*a3*x**4 - 0.000344746666666667*a0*a3*x**3 - 0.0448810666666667*a0*a3*x**2 + 0.005632*a0*a3*x - 1.04341333333333*a0*a3 - 3.1744e-7*a0*a4*x**7 + 4.36906666666667e-6*a0*a4*x**6 + 0.00209655466666667*a0*a4*x**5 - 0.0006016*a0*a4*x**4 - 0.0469717333333333*a0*a4*x**3 + 0.014592*a0*a4*x**2 - 3.13024*a0*a4*x + 8.192e-7*a0*x**3 - 9.8304e-6*a0*x**2 - 0.025686016*a0*x + 0.00036864*a0 - 1.0752e-7*a1**2*x**6 + 1.536e-6*a1**2*x**5 + 0.00114304*a1**2*x**4 - 0.00019968*a1**2*x**3 - 0.0653152*a1**2*x**2 + 0.002304*a1**2*x + 1.6*a1**2 - 3.584e-7*a1*a3*x**7 + 5.2224e-6*a1*a3*x**6 + 0.002964224*a1*a3*x**5 - 0.00078336*a1*a3*x**4 - 0.219362133333333*a1*a3*x**3 + 0.018176*a1*a3*x**2 + 5.40309333333333*a1*a3*x - 0.0768*a1*a3 - 5.4272e-7*a1*a4*x**8 + 7.9872e-6*a1*a4*x**7 + 0.00354926933333333*a1*a4*x**6 - 0.0013184*a1*a4*x**5 - 0.288405333333333*a1*a4*x**4 + 0.041472*a1*a4*x**3 + 6.60928*a1*a4*x**2 - 0.2304*a1*a4*x + 2.4576e-6*a1*x**4 - 2.94912e-5*a1*x**3 - 0.030978048*a1*x**2 + 0.00110592*a1*x + 1.536*a1 + 2.304e-12*a2**2*x**8 - 6.144e-11*a2**2*x**7 - 3.61984e-9*a2**2*x**6 + 2.602496e-7*a2**2*x**5 + 0.0003620370816*a2**2*x**4 - 4.5268992e-5*a2**2*x**3 - 0.07233404096*a2**2*x**2 - 0.0031338048*a2**2*x + 3.563955076*a2**2 - 2.8672e-7*a3**2*x**8 + 4.3008e-6*a3**2*x**7 + 0.00199389866666667*a3**2*x**6 - 0.00073728*a3**2*x**5 - 0.187746133333333*a3**2*x**4 + 0.0249173333333333*a3**2*x**3 + 5.47285333333333*a3**2*x**2 - 0.2304*a3**2*x - 0.864*a3**2 - 8.46506666666667e-7*a3*a4*x**9 + 1.29024e-5*a3*a4*x**8 + 0.00492578133333333*a3*a4*x**7 - 0.00241834666666667*a3*a4*x**6 - 0.513271466666667*a3*a4*x**5 + 0.100608*a3*a4*x**4 + 15.5844266666667*a3*a4*x**3 - 1.152*a3*a4*x* ...
# 2. Integrating ...
# g=                   2
# 38.5951129774038⋅a₀  + 125.147092817995⋅a₀⋅a₁ - 8.40638006124768e-15⋅a₀⋅a₂ + 9
#
#
# 64.244214784741⋅a₀⋅a₃ + 3678.9562769047⋅a₀⋅a₄ - 1.99214490940771e-14⋅a₀⋅d₁ - 1
#
#                                                                     2
# .08325013972071e-13⋅a₀⋅d₂ + 88.2811155184783⋅a₀ + 508.48823970163⋅a₁  - 9.5616
#
#
# 1133426519e-14⋅a₁⋅a₂ + 3913.35588020395⋅a₁⋅a₃ + 31472.4279762676⋅a₁⋅a₄ + 5.289
#
#
# 67026706147e-14⋅a₁⋅d₁ + 6.65595956627223e-13⋅a₁⋅d₂ + 736.166997004062⋅a₁ + 19.
#
#                2
# 238463106873⋅a₂  - 1.19125038549014e-13⋅a₂⋅a₃ - 1.54156089138643e-11⋅a₂⋅a₄ + 4
#
#                                             2
# .62820668279649e-14⋅a₂ + 16106.3814288598⋅a₃  + 172508.950401991⋅a₃⋅a₄ - 2.101
#
#
# 32087658619e-12⋅a₃⋅d₁ - 1.65275147113549e-11⋅a₃⋅d₂ + 3311.22839704616⋅a₃ + 727
#
#                 2
# 812.496048127⋅a₄  + 9.51079876764306e-14⋅a₄⋅d₁ + 7.21428124127696e-11⋅a₄⋅d₂ +
#
#
# 27442.5707274963⋅a₄ + 1.58371992768702e-14⋅d₁ + 1.22362437642615e-13⋅d₂ + 401.
#
#
# 360547984155
# ==================================================

# %%
g = substitute(g, [v0,v1, m, H0, L], [v0_,v1_, m_, H0_, L_])
#for i in
d_a0 = diff(g, a0);d_a1 = diff(g, a1);d_a2 = diff(g, a2);d_a3 = diff(g, a3);d_a4 = diff(g, a4);
d_d1 = diff(g, d1);d_d2 = diff(g, d2)
# p2 = substitute(p,[x], [L_]) - 1
p2 = substitute(p,[x], [L_]) - 1;p1 = substitute(p, [x], [-L_])
print("d_a0=", d_a0);print("d_a1=", d_a1);print("d_a2", d_a2);print("d_a3=", d_a3);print("d_a4", d_a4);
print("d_d1=", d_d1);print("d_d2=", d_d2);print("p2=", p2);print('=' * 100)
# Out:
# d_a0= 77.1902259548077*a0 + 125.147092817995*a1 - 8.40638006124768e-15*a2 + 964.244214784741*a3 + 3678.9562769047*a4 - 1.99214490940771e-14*d1 - 1.08325013972071e-13*d2 + 88.2811155184783
# d_a1= 125.147092817995*a0 + 1016.97647940326*a1 - 9.56161133426519e-14*a2 + 3913.35588020395*a3 + 31472.4279762676*a4 + 5.28967026706147e-14*d1 + 6.65595956627223e-13*d2 + 736.166997004062
# d_a2 -8.40638006124768e-15*a0 - 9.56161133426519e-14*a1 + 38.4769262137459*a2 - 1.19125038549014e-13*a3 - 1.54156089138643e-11*a4 + 4.62820668279649e-14
# d_a3= 964.244214784741*a0 + 3913.35588020395*a1 - 1.19125038549014e-13*a2 + 32212.7628577197*a3 + 172508.950401991*a4 - 2.10132087658619e-12*d1 - 1.65275147113549e-11*d2 + 3311.22839704616
# d_a4 3678.9562769047*a0 + 31472.4279762676*a1 - 1.54156089138643e-11*a2 + 172508.950401991*a3 + 1455624.99209625*a4 + 9.51079876764306e-14*d1 + 7.21428124127696e-11*d2 + 27442.5707274963
# d_d1= -1.99214490940771e-14*a0 + 5.28967026706147e-14*a1 - 2.10132087658619e-12*a3 + 9.51079876764306e-14*a4 + 1.58371992768702e-14
# d_d2= -1.08325013972071e-13*a0 + 6.65595956627223e-13*a1 - 1.65275147113549e-11*a3 + 7.21428124127696e-11*a4 + 1.22362437642615e-13
# p2= 10*d1 + 100*d2 - 1
# ====================================================================================================

# %%
print('1. Solving all partial derivatives equal to 0')
variables =[a0,a1,a2,a3,a4, d1, d2]
result = solve([d_a0,d_a1,d_a2, d_a3,d_a4, d_d1, d_d2], variables)
if len(result) == 0:
    print('No solutions!')
else:
    print('1. Building plot')
    vx1 = substitute(vx, variables, result[0])
    print('=' * 100)
    vx1 = substitute(vx1, [v0,v1, H0, L], [v0_,v1_,  H0_, L_])
    print("vx = ", vx);print("vx1 = ", vx1);print('-' * 100)
    vx1 = substitute(vx1, [y], [0])
    print("vx1 = ", vx1);print('=' * 100)
    pl1 = sympy.plotting.plot(vx1, xlim=(-L_, (L_ + 0.1)), ylim=(-(10 + 1), (10+1)), ylabel='vx')
# Out:
# 1. Solving all partial derivatives equal to 0
# --------------------------------------------------

# %%
if len(result) == 0:
    print('No solutions!')
else:
    print('2. Building plot')
    vy1 = substitute(vy, variables, result[0])
    print('=' * 100)
    vy1 = substitute(vy1, [v0,v1,  H0, L], [v0_,v1_, H0_, L_])
    print("vy = ", vy)
    print("vy1 = ", vy1)
    print('-' * 100)
    vy1 = substitute(vy1, [x], [0])
    print("vy1 = ", vy1)
    print(nonlinsolve([vy1], [y]))
    print(substitute(vy1, [y], [0]))
    p2 = sympy.plotting.plot(vy1, xlim=(-1, (1 + 0.1)), ylim=(-(0.3), (0.3)), ylabel='vy')
